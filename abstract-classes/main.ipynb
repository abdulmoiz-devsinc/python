# %%
from abc import ABC,abstractmethod

# %%
class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

class Toyota(Vehicle):
    def engine(self):
        print("engine started")

t=Toyota()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       7     def engine(self):
#       8         print("engine started")
# ---> 10 t=Toyota()
#
# TypeError: Can't instantiate abstract class Toyota with abstract method start
