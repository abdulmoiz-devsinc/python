# %%
class WelcomeMessage:
    def __enter__(self):
        print("Hello user! ")
    
    def __exit__(self,excType,excVal,traceback):
        print("Bye Bye User")
        #print("Program ended with: ", excType, excVal, traceback)

# %%
with WelcomeMessage() as w:
    print("123")
    raise ZeroDivisionError("ERROR MESSAGE")
print("456")
# Out:
# Hello user!
# 123
# Bye Bye User
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 with WelcomeMessage() as w:
#       2     print("123")
# ----> 3     raise ZeroDivisionError("ERROR MESSAGE")
#       4 print("456")
#
# ZeroDivisionError: ERROR MESSAGE
