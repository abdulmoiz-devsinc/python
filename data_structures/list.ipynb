# %%
# mutable, indexes and any types
my_list=[1,"my"]

# %%
my_list
# Out:
# [1, 'my']

# %%
#shallow copy
a=my_list

# %%
a
# Out:
# [1, 'my']

# %%
my_list[1]=1

# %%
a
# Out:
# [1, 1]

# %%
b=my_list[:]

# %%
b
# Out:
# [1, 1]

# %%
my_list[1]="my"

# %%
b
# Out:
# [1, 1]

# %%
my_list
# Out:
# [1, 'my']

# %%
squares = [x*x for x in range(10) if x % 2 == 0]

# %%
squares
# Out:
# [0, 4, 16, 36, 64]

# %%
tup=([1,2],4,5)

# %%
tup[0].append(3)

# %%
tup
# Out:
# ([1, 2, 3], 4, 5)

# %%
type((1))
# Out:
# int

# %%
type((1,))
# Out:
# tuple

# %%
type([1])
# Out:
# list

# %%
a, *b = (1,2,3,4)

# %%
b
# Out:
# [2, 3, 4]

# %%
c, d = (1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c, d = (1,2,3,4)
#
# ValueError: too many values to unpack (expected 2)

# %%
data = {
  "user": {
    "profile": {
      "name": "Moiz"
    }
  }
}

# %%
data.get("user","none").get("profile","none").get("name","xyz")
# Out:
# 'Moiz'

# %%
data["user"]["profile"]["name"]
# Out:
# 'Moiz'

# %%
tup=(1,(2,3))

# %%
tup
# Out:
# (1, (2, 3))

# %%
sets={[1,2]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sets={[1,2]}
#
# TypeError: unhashable type: 'list'

# %%
string="hello"

# %%
string[0]='H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 string[0]='H'
#
# TypeError: 'str' object does not support item assignment
