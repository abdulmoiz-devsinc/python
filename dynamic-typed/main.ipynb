# %% [markdown]
# python is dynamic typed

# %%
def foo(a):
   if a>0: print ("hi")
   else: print("hi"+a)


foo(a=5)
# Out:
# hi

# %% [markdown]
# since it is dynamic typed else part didnt give error and it executed if it was static it would not execute and will give error

# %% [markdown]
# arr=[1,3,4]

# %%
arr=[1,2,3,4]
arr[::-1]
# Out:
# [4, 3, 2, 1]

# %%
import sys

lst = []
print(sys.getsizeof(lst))  # size of empty list object

lst2 = [0]*10
print(sys.getsizeof(lst2))  # size after 10 elements
# Out:
# 56
# 136

# %%
arr=[2,3,4,5]
tup=tuple(arr)

# %%
tup
# Out:
# (2, 3, 4, 5)

# %%
arr=list(tup)

# %%
arr
# Out:
# [2, 3, 4, 5]

# %%
my_list = [1, 2, 3]
my_tuple = (*my_list,) # The trailing comma is essential for Python to recognize it as a tuple

# %%
my_tuple
# Out:
# (1, 2, 3)
