# %%
class A:
    def greet(self):
        print("Hello from class A")

# %%
greet_outer=lambda : print("Hello from outer function")

# %%
a=A()

# %%
a.greet()
# Out:
# Hello from class A

# %%
a.greet=   greet_outer

# %%
a.greet()
# Out:
# Hello from outer function
