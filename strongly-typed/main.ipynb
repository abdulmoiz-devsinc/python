# %% [markdown]
# Python is strongly typed language which means int cant be combined with string it will give error

# %%
string="5"
x=5

# %%
string+x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 string+x
#
# TypeError: can only concatenate str (not "int") to str
